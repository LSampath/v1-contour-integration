# %%
import brian2
from brian2tools import *
from brian2 import *
from struct import unpack
from PIL import Image
import numpy as np
import matplotlib.cm as cmap
import matplotlib.pyplot as plt
import os.path
import pickle as pickle
import scipy
import scipy.signal as signal
import time
import warnings
warnings.simplefilter('ignore')
import gc

# %%
def get_matrix_from_file(fileName, shape):
    readout = np.load(fileName)
#     print(readout.shape, fileName)
    value_arr = np.zeros(shape)
    if not readout.shape == (0,):
        value_arr[np.int32(readout[:,0]), np.int32(readout[:,1])] = readout[:,2]
    return value_arr

# %%
def tune_stimuli(data):
    data = (data - data.min()) / (data.max() - data.min())
    q95 = np.percentile(data, 95)
    data = np.where((data > q95), q95, data)
    data = np.exp(data*15)
    data = (data - data.min()) / (data.max() - data.min())
    data *= 15
    return data

# %%
def gaussian2D(x, y, sigma):
    return (1.0/(1*math.pi*(sigma**2)))*math.exp(-(1.0/(sigma**2))*(x**2 + y**2))

def mexicanHat(x,y,sigma1,sigma2): 
    return gaussian2D(x,y,sigma1) - gaussian2D(x,y,sigma2)

def receptiveFieldMatrix(func):
    h = 5
    g = np.zeros((h,h))
    for xi in range(0,h):
        for yi in range(0,h):
            x = xi-int(h/2)
            y = yi-int(h/2)
            g[xi, yi] = func(x,y);
    return g

# %%
def get_stimuli(file_name):
    img = Image.open(file_name)
    img.load()
    img_arr = np.asarray(img, dtype="int32")
    stimuli = np.absolute(img_arr)/255
    img.close()
    
    stimuli_on = signal.convolve(stimuli, receptiveFieldMatrix(lambda x,y:mexicanHat(x,y,1,1.05)), mode='same')
    stimuli_on = tune_stimuli(stimuli_on)
    stimuli_off = signal.convolve(stimuli, receptiveFieldMatrix(lambda x,y:mexicanHat(x,y,1.05,1)), mode='same')
    stimuli_off = tune_stimuli(stimuli_off)

    c, axarr = subplots(1, 3, figsize = (10, 3))
    axarr[0].imshow(stimuli, cmap = cmap.get_cmap('binary'))
    axarr[0].title.set_text('stimuli')
    axarr[1].imshow(stimuli_on, cmap = cmap.get_cmap('binary'))
    axarr[1].title.set_text('stimuli_on')
    axarr[2].imshow(stimuli_off, cmap = cmap.get_cmap('binary'))
    axarr[2].title.set_text('stimuli_off')
    
    return stimuli_on, stimuli_off

# %%
def save_connections():
    for connName in connections:
        conn = connections[connName]
        weights = np.column_stack((conn.i, conn.j, conn.w))
        sparseWeights = weights[~(weights.transpose()[2] == 0)]
        np.save(saved_path + connName, sparseWeights)
        print(connName, end=' ')
    print('connections saved')

# %%
def get_surrounding(coordinate, r, inner, length):
    y = coordinate[0]
    x = coordinate[1]
    
    x_min = 0 if (x-r < 0) else (x-r)
    x_max = (length-1) if (x+r > length-1) else (x+r)
    y_min = 0 if (y-r < 0) else (y-r)
    y_max = (length-1) if (y+r > length-1) else (y+r)
    
    coordinates = []
    for i in range(y_min, y_max+1):
        for j in range(x_min, x_max+1):
            if (i==y and j==x and not inner):
                continue
            coordinates.append((i,j))
            
    return coordinates

# %%
def plot_lateral_distribution(name):
    if (name == 'L3_L3'):
        shape = (n_L3, n_L3)
        radius = 1; inner = False
    elif (name == 'L3_L2'):
        shape = (n_L3, n_L2)
        radius = 0; inner = True
        
    weights = np.array(connections[name].w)
    weights = weights.reshape(shape)
    
    # init dictionary
    list_dic = {}; sum_dic = {}; total_sum = 0
    
    c = {0:'h', 1:'v', 2:'d1', 3:'d2'}
    for s_index in range(orientations):
        for t_index in range(orientations):
            list_dic[c[s_index]+c[t_index]] = []
            sum_dic[c[s_index]+c[t_index]] = 0

    for i in range(0, c_length):                   # y axis
        for j in range(0, c_length):               # x axis
            for p,q in get_surrounding((i,j), radius, inner, c_length):
                
                for s_index in range(orientations):
                    for t_index in range(orientations):
                        target = ( p * c_length + q ) * orientations + t_index
                        source = ( i * c_length + j ) * orientations + s_index
                        list_dic[c[s_index]+c[t_index]].append(weights[source][target])
                        sum_dic[c[s_index]+c[t_index]] += abs(weights[source][target])
                        total_sum += abs(weights[source][target])
                        
    category_names = ['H', 'V', 'Diagonal (45)', 'Diagonal (135)']
    results = { 'h': [], 'v': [], 'd1': [], 'd2': [] }
    # %run horizontal_barchart_distribution.py
                        
    plt.figure(figsize=(17,4))
    for s_index in range(orientations):
        for t_index in range(orientations):
            plt.plot(list_dic[c[s_index]+c[t_index]], label=c[s_index]+c[t_index])
            
            print(c[s_index]+c[t_index], sum_dic[c[s_index]+c[t_index]], 
                  'of', total_sum, ':', sum_dic[c[s_index]+c[t_index]]*100/total_sum)
            
            results[c[s_index]].append(sum_dic[c[s_index]+c[t_index]])
    
    plt.legend(); plt.show()
    survey(results, category_names)

# %% [markdown]
# # INITIALIZE

# %%
stimuli_list = ['pic_v_1.tif', 'pic_v_2.tif', 'pic_v_3.tif', 'pic_v_4.tif', 
                'pic_v_5.tif', 'pic_v_6.tif', 'pic_v_7.tif', 'pic_v_8.tif']
#                 'pic_h_1.tif', 'pic_h_2.tif', 'pic_h_3.tif', 'pic_h_4.tif', 
#                 'pic_h_5.tif', 'pic_h_6.tif', 'pic_h_7.tif', 'pic_h_8.tif']
# stimuli_list = ['pic_h_1.tif', 'pic_h_2.tif']
seq_path = './24_seq/'

initial_path = './initial_weights/'
saved_path = './saved_weights/'

fig_num = 1

field_size = 5                     # 2/3/4/5/6
margin = (field_size//2)

c_length = 20
r_length = c_length + margin*2
orientations = 4

h_index = 0
v_index = 1
d1_index = 2
d2_index = 3

n_LGN = r_length*r_length
n_L4  = c_length*c_length*orientations
n_L3  = n_L4
n_L2  = n_L3

num_epochs = 20

single_example_time = 0.45 * second
resting_time = 0.25 * second

# delay = {}
# delay = (0*ms, 5*ms)              # min and max delay
# minDelay = delay[0]
# maxDelay = delay[1]
# deltaDelay = maxDelay - minDelay

# neural model parameters
v_rest_e = -65. * mV
v_rest_i = -60. * mV
v_reset_e = -65. * mV
v_reset_i = -45. * mV
v_thresh_e = -52. * mV
v_thresh_i = -40. * mV
refrac_e = 20. * ms
refrac_i = 15. * ms
tc_theta = 1e7 * ms
theta_plus_e = 0.2 * mV
offset = 20.0 * mV

# STDP parameters
tc_pre = 50*ms
tc_post = 40*ms
nu_pre =  0.05# 0.0001
nu_post = 0.1 # 0.01
wmax = 100.0
Apre = 0.4
Apost = Apre*1.05

input_intensity = 1.
start_input_intensity = input_intensity

#membrane dynamics
scr_e = 'v = v_reset_e; theta += theta_plus_e; timer = 0*ms'
v_reset_i_str = 'v = v_reset_i'

v_thresh_e_str = '(v > (theta - offset + v_thresh_e)) and (timer > refrac_e)'
v_thresh_i_str = 'v > v_thresh_i'

neuron_eqs_e = '''
        dv/dt = ((v_rest_e - v) + g_e*(-v) + g_i*(-100.*mV - v) ) / (100*ms)  : volt (unless refractory)
        dg_e/dt = -g_e/(1.0*ms)                                    : 1
        dg_i/dt = -g_i/(2.0*ms)                                    : 1
        dtheta/dt = -theta/(1e7*ms)                                : volt
        dtimer/dt = 0.1                                            : second
'''

neuron_eqs_i = '''
        dv/dt = ((v_rest_i - v) +  g_e*(-v) + g_i*(-85.*mV - v)) / (10*ms)  : volt (unless refractory)
        dg_e/dt = -g_e/(1.0*ms)                                    : 1
        dg_i/dt = -g_i/(2.0*ms)                                    : 1
'''

# learning rules
# without STDP
model = 'w : 1'
pre_e = 'g_e_post += w'
pre_i = 'g_i_post += w'
post = ''

stdp_model = '''
    post2_temp                          : 1
    w                                   : 1
    dpre/dt   =   -pre/(tc_pre)         : 1 (event-driven)
    dpost/dt  =   -post/(tc_post)       : 1 (event-driven)
'''
stdp_pre = '''
    w = clip(w + nu_pre*post, -wmax, wmax) * int(post>0.3*Apost) + clip(w - nu_pre*post, -wmax, wmax) * int(post<=0.3*Apost);
    pre += Apre;
'''
stdp_pre_e = stdp_pre + 'g_e_post += w;'
stdp_pre_i = stdp_pre + 'g_i_post += w;'
stdp_post  = 'w = clip(w + nu_post * pre, 0, wmax); post += Apost;'

# %%
# stimuli_on, stimuli_off = load_stimuli('./pic_60_1.tif')

# %%
neuron_groups = {}
neuron_groups_list = [
    ('L4_i_NF', 'i'), ('L4_NF', 'e'), ('L4_i_FN', 'i'), ('L4_FN', 'e'),
    ('L4', 'e'), 
    ('L3', 'e'), 
    ('L2', 'i')
]

for name, e_i in neuron_groups_list:
    if (e_i == 'e'):
        neuron_groups[name] = NeuronGroup(n_L4, neuron_eqs_e, threshold=v_thresh_e_str, refractory=refrac_e, reset=scr_e, method='euler')
        neuron_groups[name].v    = v_rest_e - 40.*mV 
        neuron_groups[name].theta = np.ones((n_L4)) * 20.0*mV
    elif (e_i == 'i'):
        neuron_groups[name] = NeuronGroup(n_L4, neuron_eqs_i, threshold=v_thresh_i_str, refractory=refrac_i, reset=v_reset_i_str, method='euler')
        neuron_groups[name].v    = v_rest_i - 40.*mV 

input_groups = {}
input_groups['LGN_on']   = PoissonGroup(n_LGN, 0*Hz)
input_groups['LGN_off']  = PoissonGroup(n_LGN, 0*Hz)

gc.collect()
# Out:
# 1392

# %%
weight_path = initial_path
# weight_path = saved_path
connections = {}
#[name, shape, weight_file, source, target, equation_type]

input_neuron_conn = [
    ['LGN_on_L4_NF', (n_LGN, n_L4), 'LGN_L4_NF.npy', 'LGN_on', 'L4_NF', 'e'],
    ['LGN_off_L4_NF', (n_LGN, n_L4), 'LGN_L4_FN.npy', 'LGN_off', 'L4_NF', 'e'],
    ['LGN_off_L4_i_NF', (n_LGN, n_L4), 'LGN_L4_NF.npy', 'LGN_off', 'L4_i_NF', 'e'],
    ['LGN_on_L4_i_NF', (n_LGN, n_L4), 'LGN_L4_FN.npy', 'LGN_on', 'L4_i_NF', 'e'],
    
    ['LGN_off_L4_FN', (n_LGN, n_L4), 'LGN_L4_NF.npy', 'LGN_off', 'L4_FN', 'e'],
    ['LGN_on_L4_FN', (n_LGN, n_L4), 'LGN_L4_FN.npy', 'LGN_on', 'L4_FN', 'e'],
    ['LGN_on_L4_i_FN', (n_LGN, n_L4), 'LGN_L4_NF.npy', 'LGN_on', 'L4_i_FN', 'e'],
    ['LGN_off_L4_i_FN', (n_LGN, n_L4), 'LGN_L4_FN.npy', 'LGN_off', 'L4_i_FN', 'e'],
]

neuron_neuron_conn = [
    ['L4_i_L4_NF', (n_L4, n_L4), 'L4_L4.npy', 'L4_i_NF', 'L4_NF', 'i', False],
    ['L4_i_L4_FN', (n_L4, n_L4), 'L4_L4.npy', 'L4_i_FN', 'L4_FN', 'i', False],
    ['L4_NF_L4', (n_L4, n_L4), 'L4_L4.npy', 'L4_NF', 'L4', 'e', False],
    ['L4_FN_L4', (n_L4, n_L4), 'L4_L4.npy', 'L4_FN', 'L4', 'e', False],
    
    ['L4_L3', (n_L4, n_L3), 'L4_L3.npy', 'L4', 'L3', 'e', False],
    ['L3_L3', (n_L3, n_L3), 'L3_L3.npy', 'L3', 'L3', 'e', True],
    ['L3_L2', (n_L3, n_L2), 'L3_L2.npy', 'L3', 'L2', 'e', False],
    ['L2_L3', (n_L2, n_L3), 'L2_L3.npy', 'L2', 'L3', 'i', False],
    
    ['L3_L4', (n_L3, n_L4), 'L3_L4.npy', 'L3', 'L4', 'e', False]
]


for name, shape, weight_file, source, target, _ in input_neuron_conn:
    weightMatrix = get_matrix_from_file(weight_path + weight_file, shape)
    connections[name]= Synapses(input_groups[source], neuron_groups[target], model=model, on_pre=pre_e, on_post=post)
    connections[name].connect(True)
    connections[name].w = weightMatrix[connections[name].i, connections[name].j]
#     connections[name].delay = 'minDelay + rand() * deltaDelay'
    
    
for name, shape, weight_file, source, target, equation, learn in neuron_neuron_conn:
    if (learn):
        model_eq = stdp_model
        post_eq = stdp_post
        if (equation == 'e'):
            pre_eq = stdp_pre_e
        elif (equation == 'i'):
            pre_eq = stdp_pre_i
    else:
        model_eq = model
        post_eq = post
        if (equation == 'e'):
            pre_eq = pre_e
        elif (equation == 'i'):
            pre_eq = pre_i
    
    weightMatrix = get_matrix_from_file(weight_path + weight_file, shape)
    connections[name]= Synapses(neuron_groups[source], neuron_groups[target], model=model_eq, on_pre=pre_eq, on_post=post_eq)
    connections[name].connect(True)
    connections[name].w = weightMatrix[connections[name].i, connections[name].j]
    
gc.collect()
# Out:
# WARNING    Cannot use Cython, a test compilation failed: Microsoft Visual C++ 14.0 is required. Get it with "Microsoft Visual C++ Build Tools": https://visualstudio.microsoft.com/downloads/ (DistutilsPlatformError) [brian2.codegen.runtime.cython_rt.cython_rt.failed_compile_test]
# INFO       Cannot use compiled code, falling back to the numpy code generation target. Note that this will likely be slower than using compiled code. Set the code generation to numpy manually to avoid this message:
# prefs.codegen.target = "numpy" [brian2.devices.device.codegen_fallback]
# 1816

# %%
spike_monitors = {}

spike_monitors['LGN_on']      = SpikeMonitor(input_groups['LGN_on'])
spike_monitors['LGN_off']     = SpikeMonitor(input_groups['LGN_off'])

for name,_ in neuron_groups_list:
    spike_monitors[name]   = SpikeMonitor(neuron_groups[name])

# %%
net = Network()
for obj_list in [neuron_groups, input_groups, connections, spike_monitors]:
    for key in obj_list:
        net.add(obj_list[key])

# %%
plot_lateral_distribution('L3_L3')
# Out:
# hh 904.1681467277891 of 14464.433917303193 : 6.25097499077493
# hv 904.1846744106766 of 14464.433917303193 : 6.251089255066101
# hd1 904.0216594357779 of 14464.433917303193 : 6.24996224950314
# hd2 904.071696066359 of 14464.433917303193 : 6.250308178219516
# vh 903.9505886097554 of 14464.433917303193 : 6.249470900678646
# vv 904.0215216850142 of 14464.433917303193 : 6.24996129716194
# vd1 903.6473793633883 of 14464.433917303193 : 6.247374660700638
# vd2 904.2044230570222 of 14464.433917303193 : 6.251225787518449
# d1h 904.0247329483707 of 14464.433917303193 : 6.249983498261373
# d1v 904.191635375804 of 14464.433917303193 : 6.251137379764013
# d1d1 903.9240309605126 of 14464.433917303193 : 6.249287294120694
# d1d2 904.1553065625372 of 14464.433917303193 : 6.250886220171633
# d2h 904.1684506319306 of 14464.433917303193 : 6.250977091819072
# d2v 903.8548348141863 of 14464.433917303193 : 6.24880890591192
# d2d1 904.0084911016769 of 14464.433917303193 : 6.249871210101418
# d2d2 903.8363455524325 of 14464.433917303193 : 6.248681080226798

# %%
# plot_lateral_distribution('L3_L2')

# %%
# load stimuli files
# stimuli_on, stimuli_off = get_stimuli(stimuli_file_path)

# %% [markdown]
# # TRAIN

# %%
previous_spike_count = np.zeros(n_L4)

for stimuli_file in stimuli_list:
    net.run(resting_time)
    
    for name, e_i in neuron_groups_list:
        if (e_i == 'e'):
            neuron_groups[name].theta = np.ones((n_L4)) * 20.0*mV
            
    stimuli_on, stimuli_off = get_stimuli(seq_path + stimuli_file)

    j = 0
    while j < (num_epochs):
        spike_rates_on = stimuli_on.reshape((n_LGN)) / 8. * input_intensity
        spike_rates_off = stimuli_off.reshape((n_LGN)) / 8. * input_intensity

        input_groups['LGN_on'].rates = spike_rates_on * Hz
        input_groups['LGN_off'].rates = spike_rates_off * Hz

        print('run example number:', j+1, 'of', num_epochs, 'for', stimuli_file)
        net.run(single_example_time, report='text')   # 0.35 s

        current_spike_count = np.asarray(spike_monitors['L4'].count[:]) - previous_spike_count
        previous_spike_count = np.copy(spike_monitors['L4'].count[:])

        if np.sum(current_spike_count) < 1:
            if (input_intensity == 5):
                break;
            print("F - spike count", np.sum(current_spike_count))
            input_intensity += 1 
        else:     
            print("S - spike count", np.sum(current_spike_count))
            input_intensity = start_input_intensity
            j += 1

        input_groups['LGN_on'].rates = 0 * Hz
        input_groups['LGN_off'].rates = 0 * Hz
        net.run(resting_time)

        gc.collect()
# Out:
# run example number: 1 of 20 for pic_v_1.tif
# Starting simulation at t=250. ms for a duration of 0.45 s
# 0.28890000000000005 (64%) simulated in 10s, estimated 6s remaining.
# 0.45 (100%) simulated in 10s
# S - spike count 240.0
# run example number: 2 of 20 for pic_v_1.tif
# Starting simulation at t=0.95 s for a duration of 0.45 s
# 0.14133214285714293 (31%) simulated in 10s, estimated 22s remaining.
# 0.45 (100%) simulated in 10s
# S - spike count 228
# run example number: 3 of 20 for pic_v_1.tif
# Starting simulation at t=1.65 s for a duration of 0.45 s
# 0.08997857142857146 (19%) simulated in 10s, estimated 40s remaining.
# 0.45 (100%) simulated in 10s
# S - spike count 226
# run example number: 4 of 20 for pic_v_1.tif
# Starting simulation at t=2.35 s for a duration of 0.45 s
# 0.06785357142857144 (15%) simulated in 10s, estimated 56s remaining.
# 0.45 (100%) simulated in 10s
# S - spike count 107
# run example number: 5 of 20 for pic_v_1.tif
# Starting simulation at t=3.05 s for a duration of 0.45 s
# 0.051467142857142864 (11%) simulated in 10s, estimated 1m 17s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 174
# run example number: 6 of 20 for pic_v_1.tif
# Starting simulation at t=3.75 s for a duration of 0.45 s
# 0.04234285714285709 (9%) simulated in 10s, estimated 1m 36s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 205
# run example number: 7 of 20 for pic_v_1.tif
# Starting simulation at t=4.45 s for a duration of 0.45 s
# 0.037065306122448974 (8%) simulated in 10s, estimated 1m 51s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 190
# run example number: 8 of 20 for pic_v_1.tif
# Starting simulation at t=5.15 s for a duration of 0.45 s
# 0.03197410714285714 (7%) simulated in 10s, estimated 2m 11s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 119
# run example number: 9 of 20 for pic_v_1.tif
# Starting simulation at t=5.85 s for a duration of 0.45 s
# 0.028378571428571395 (6%) simulated in 10s, estimated 2m 29s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 127
# run example number: 10 of 20 for pic_v_1.tif
# Starting simulation at t=6.55 s for a duration of 0.45 s
# 0.01951714285714282 (4%) simulated in 10s, estimated 3m 41s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 162
# run example number: 11 of 20 for pic_v_1.tif
# Starting simulation at t=7.25 s for a duration of 0.45 s
# 0.019992857142857107 (4%) simulated in 10s, estimated 3m 35s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 99
# run example number: 12 of 20 for pic_v_1.tif
# Starting simulation at t=7.95 s for a duration of 0.45 s
# 0.016880357142857103 (3%) simulated in 10s, estimated 4m 17s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 139
# run example number: 13 of 20 for pic_v_1.tif
# Starting simulation at t=8.65 s for a duration of 0.45 s
# 0.019414285714285707 (4%) simulated in 10s, estimated 3m 42s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 104
# run example number: 14 of 20 for pic_v_1.tif
# Starting simulation at t=9.35 s for a duration of 0.45 s
# 0.018156122448979614 (4%) simulated in 10s, estimated 3m 58s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 84
# run example number: 15 of 20 for pic_v_1.tif
# Starting simulation at t=10.05 s for a duration of 0.45 s
# 0.016834285714285767 (3%) simulated in 10s, estimated 4m 17s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 103
# run example number: 16 of 20 for pic_v_1.tif
# Starting simulation at t=10.75 s for a duration of 0.45 s
# 0.015472767857142985 (3%) simulated in 10s, estimated 4m 41s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 156
# run example number: 17 of 20 for pic_v_1.tif
# Starting simulation at t=11.45 s for a duration of 0.45 s
# 0.0142563025210085 (3%) simulated in 10s, estimated 5m 6s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 115
# run example number: 18 of 20 for pic_v_1.tif
# Starting simulation at t=12.15 s for a duration of 0.45 s
# 0.014203571428571572 (3%) simulated in 10s, estimated 5m 7s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 65
# run example number: 19 of 20 for pic_v_1.tif
# Starting simulation at t=12.85 s for a duration of 0.45 s
# 0.012789473684210654 (2%) simulated in 10s, estimated 5m 42s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 133
# run example number: 20 of 20 for pic_v_1.tif
# Starting simulation at t=13.55 s for a duration of 0.45 s
# 0.012583928571428768 (2%) simulated in 10s, estimated 5m 48s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 58
# run example number: 1 of 20 for pic_v_2.tif
# Starting simulation at t=14.5 s for a duration of 0.45 s
# 0.010541137123746014 (2%) simulated in 10s, estimated 6m 57s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 201
# run example number: 2 of 20 for pic_v_2.tif
# Starting simulation at t=15.2 s for a duration of 0.45 s
# 0.010952396166134408 (2%) simulated in 10s, estimated 6m 41s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 142
# run example number: 3 of 20 for pic_v_2.tif
# Starting simulation at t=15.9 s for a duration of 0.45 s
# 0.010604587155963477 (2%) simulated in 10s, estimated 6m 55s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 139
# run example number: 4 of 20 for pic_v_2.tif
# Starting simulation at t=16.6 s for a duration of 0.45 s
# 0.010108504398827147 (2%) simulated in 10s, estimated 7m 16s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 130
# run example number: 5 of 20 for pic_v_2.tif
# Starting simulation at t=17.3 s for a duration of 0.45 s
# 0.009250985915493108 (2%) simulated in 10s, estimated 7m 57s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 185
# run example number: 6 of 20 for pic_v_2.tif
# Starting simulation at t=18. s for a duration of 0.45 s
# 0.008187804878048937 (1%) simulated in 10s, estimated 9m 0s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 138
# run example number: 7 of 20 for pic_v_2.tif
# Starting simulation at t=18.7 s for a duration of 0.45 s
# 0.009366579634464967 (2%) simulated in 10s, estimated 7m 51s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 115
# run example number: 8 of 20 for pic_v_2.tif
# Starting simulation at t=19.4 s for a duration of 0.45 s
# 0.008394710327456171 (1%) simulated in 10s, estimated 8m 46s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 123
# run example number: 9 of 20 for pic_v_2.tif
# Starting simulation at t=20.1 s for a duration of 0.45 s
# 0.0068343065693433225 (1%) simulated in 10s, estimated 10m 49s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 100
# run example number: 10 of 20 for pic_v_2.tif
# Starting simulation at t=20.8 s for a duration of 0.45 s
# 0.006583764705882586 (1%) simulated in 10s, estimated 11m 14s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 105
# run example number: 11 of 20 for pic_v_2.tif
# Starting simulation at t=21.5 s for a duration of 0.45 s
# 0.0071015945330298895 (1%) simulated in 10s, estimated 10m 24s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 212
# run example number: 12 of 20 for pic_v_2.tif
# Starting simulation at t=22.2 s for a duration of 0.45 s
# 0.006441059602649245 (1%) simulated in 10s, estimated 11m 29s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 130
# run example number: 13 of 20 for pic_v_2.tif
# Starting simulation at t=22.9 s for a duration of 0.45 s
# 0.006045610278372883 (1%) simulated in 10s, estimated 12m 14s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 119
# run example number: 14 of 20 for pic_v_2.tif
# Starting simulation at t=23.6 s for a duration of 0.45 s
# 0.0052970893970896845 (1%) simulated in 10s, estimated 14m 0s remaining.
# 0.45 (100%) simulated in 15s
# S - spike count 162
# run example number: 15 of 20 for pic_v_2.tif
# Starting simulation at t=24.3 s for a duration of 0.45 s
# 0.005601818181818436 (1%) simulated in 10s, estimated 13m 13s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 123
# run example number: 16 of 20 for pic_v_2.tif
# Starting simulation at t=25. s for a duration of 0.45 s
# 0.006588212180746853 (1%) simulated in 10s, estimated 11m 14s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 113
# run example number: 17 of 20 for pic_v_2.tif
# Starting simulation at t=25.7 s for a duration of 0.45 s
# 0.006551242829828181 (1%) simulated in 10s, estimated 11m 18s remaining.
# 0.45 (100%) simulated in 11s
# S - spike count 64
# run example number: 18 of 20 for pic_v_2.tif
# Starting simulation at t=26.4 s for a duration of 0.45 s
# 0.00614581005586619 (1%) simulated in 10s, estimated 12m 3s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 114
# run example number: 19 of 20 for pic_v_2.tif
# Starting simulation at t=27.1 s for a duration of 0.45 s
# 0.005509437386570151 (1%) simulated in 10s, estimated 13m 27s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 113
# run example number: 20 of 20 for pic_v_2.tif
# Starting simulation at t=27.8 s for a duration of 0.45 s
# 0.004890265486725984 (1%) simulated in 10s, estimated 15m 10s remaining.
# 0.45 (100%) simulated in 15s
# S - spike count 102
# run example number: 1 of 20 for pic_v_3.tif
# Starting simulation at t=28.75 s for a duration of 0.45 s
# 0.00422722602739754 (0%) simulated in 10s, estimated 17m 35s remaining.
# 0.45 (100%) simulated in 15s
# S - spike count 221
# run example number: 2 of 20 for pic_v_3.tif
# Starting simulation at t=29.45 s for a duration of 0.45 s
# 0.004534615384615674 (1%) simulated in 10s, estimated 16m 23s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 200
# run example number: 3 of 20 for pic_v_3.tif
# Starting simulation at t=30.15 s for a duration of 0.45 s
# 0.005082352941176803 (1%) simulated in 10s, estimated 14m 36s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 166
# run example number: 4 of 20 for pic_v_3.tif
# Starting simulation at t=30.85 s for a duration of 0.45 s
# 0.004448242811501909 (0%) simulated in 10s, estimated 16m 42s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 143
# run example number: 5 of 20 for pic_v_3.tif
# Starting simulation at t=31.55 s for a duration of 0.45 s
# 0.00438328125000033 (0%) simulated in 10s, estimated 16m 57s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 146
# run example number: 6 of 20 for pic_v_3.tif
# Starting simulation at t=32.25 s for a duration of 0.45 s
# 0.004140825688073672 (0%) simulated in 10s, estimated 17m 58s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 251
# run example number: 7 of 20 for pic_v_3.tif
# Starting simulation at t=32.95 s for a duration of 0.45 s
# 0.004293862275449388 (0%) simulated in 10s, estimated 17m 18s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 159
# run example number: 8 of 20 for pic_v_3.tif
# Starting simulation at t=33.65 s for a duration of 0.45 s
# 0.004203079178885823 (0%) simulated in 10s, estimated 17m 41s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 153
# run example number: 9 of 20 for pic_v_3.tif
# Starting simulation at t=34.35 s for a duration of 0.45 s
# 0.003962068965517472 (0%) simulated in 10s, estimated 18m 46s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 150
# run example number: 10 of 20 for pic_v_3.tif
# Starting simulation at t=35.05 s for a duration of 0.45 s
# 0.003981549295774781 (0%) simulated in 10s, estimated 18m 40s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 148
# run example number: 11 of 20 for pic_v_3.tif
# Starting simulation at t=35.75 s for a duration of 0.45 s
# 0.0038001381215470704 (0%) simulated in 10s, estimated 19m 34s remaining.
# 0.45 (100%) simulated in 15s
# S - spike count 221
# run example number: 12 of 20 for pic_v_3.tif
# Starting simulation at t=36.45 s for a duration of 0.45 s
# 0.0034560975609757008 (0%) simulated in 10s, estimated 21m 33s remaining.
# 0.45 (100%) simulated in 15s
# S - spike count 198
# run example number: 13 of 20 for pic_v_3.tif
# Starting simulation at t=37.15 s for a duration of 0.45 s
# 0.0036023936170212997 (0%) simulated in 10s, estimated 20m 39s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 201
# run example number: 14 of 20 for pic_v_3.tif
# Starting simulation at t=37.85 s for a duration of 0.45 s
# 0.0037057441253264163 (0%) simulated in 10s, estimated 20m 4s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 152
# run example number: 15 of 20 for pic_v_3.tif
# Starting simulation at t=38.55 s for a duration of 0.45 s
# 0.0033923076923076563 (0%) simulated in 10s, estimated 21m 57s remaining.
# 0.45 (100%) simulated in 15s
# S - spike count 147
# run example number: 16 of 20 for pic_v_3.tif
# Starting simulation at t=39.25 s for a duration of 0.45 s
# 0.003443576826196421 (0%) simulated in 10s, estimated 21m 37s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 113
# run example number: 17 of 20 for pic_v_3.tif
# Starting simulation at t=39.95 s for a duration of 0.45 s
# 0.0034563118811880168 (0%) simulated in 10s, estimated 21m 32s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 141
# run example number: 18 of 20 for pic_v_3.tif
# Starting simulation at t=40.65 s for a duration of 0.45 s
# 0.003372262773722547 (0%) simulated in 10s, estimated 22m 5s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 115
# run example number: 19 of 20 for pic_v_3.tif
# Starting simulation at t=41.35 s for a duration of 0.45 s
# 0.003627990430621891 (0%) simulated in 10s, estimated 20m 32s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 125
# run example number: 20 of 20 for pic_v_3.tif
# Starting simulation at t=42.05 s for a duration of 0.45 s
# 0.003602117647058627 (0%) simulated in 10s, estimated 20m 39s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 125
# run example number: 1 of 20 for pic_v_4.tif
# Starting simulation at t=43. s for a duration of 0.45 s
# 0.0030189873417719214 (0%) simulated in 10s, estimated 24m 41s remaining.
# 0.45 (100%) simulated in 15s
# S - spike count 191
# run example number: 2 of 20 for pic_v_4.tif
# Starting simulation at t=43.7 s for a duration of 0.45 s
# 0.003437938844846883 (0%) simulated in 10s, estimated 21m 41s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 130
# run example number: 3 of 20 for pic_v_4.tif
# Starting simulation at t=44.4 s for a duration of 0.45 s
# 0.0034876254180599836 (0%) simulated in 10s, estimated 21m 22s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 203
# run example number: 4 of 20 for pic_v_4.tif
# Starting simulation at t=45.1 s for a duration of 0.45 s
# 0.0035812294182214935 (0%) simulated in 10s, estimated 20m 47s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 173
# run example number: 5 of 20 for pic_v_4.tif
# Starting simulation at t=45.8 s for a duration of 0.45 s
# 0.002972432432432105 (0%) simulated in 10s, estimated 25m 5s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 120
# run example number: 6 of 20 for pic_v_4.tif
# Starting simulation at t=46.5 s for a duration of 0.45 s
# 0.0032386581469645587 (0%) simulated in 10s, estimated 23m 0s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 149
# run example number: 7 of 20 for pic_v_4.tif
# Starting simulation at t=47.2 s for a duration of 0.45 s
# 0.003424344176285081 (0%) simulated in 10s, estimated 21m 44s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 73
# run example number: 8 of 20 for pic_v_4.tif
# Starting simulation at t=47.9 s for a duration of 0.45 s
# 0.0029084798345394808 (0%) simulated in 10s, estimated 25m 37s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 125
# run example number: 9 of 20 for pic_v_4.tif
# Starting simulation at t=48.6 s for a duration of 0.45 s
# 0.0027761467889904153 (0%) simulated in 10s, estimated 26m 51s remaining.
# 0.45 (100%) simulated in 15s
# S - spike count 131
# run example number: 10 of 20 for pic_v_4.tif
# Starting simulation at t=49.3 s for a duration of 0.45 s
# 0.0029776884422106683 (0%) simulated in 10s, estimated 25m 3s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 132
# run example number: 11 of 20 for pic_v_4.tif
# Starting simulation at t=50. s for a duration of 0.45 s
# 0.0028186323092166225 (0%) simulated in 10s, estimated 26m 27s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 117
# run example number: 12 of 20 for pic_v_4.tif
# Starting simulation at t=50.7 s for a duration of 0.45 s
# 0.0027853372434013287 (0%) simulated in 10s, estimated 26m 46s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 125
# run example number: 13 of 20 for pic_v_4.tif
# Starting simulation at t=51.4 s for a duration of 0.45 s
# 0.0023233365477333947 (0%) simulated in 10s, estimated 32m 7s remaining.
# 0.45 (100%) simulated in 15s
# S - spike count 178
# run example number: 14 of 20 for pic_v_4.tif
# Starting simulation at t=52.1 s for a duration of 0.45 s
# 0.0025784015223591517 (0%) simulated in 10s, estimated 28m 56s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 103
# run example number: 15 of 20 for pic_v_4.tif
# Starting simulation at t=52.8 s for a duration of 0.45 s
# 0.002677183098591071 (0%) simulated in 10s, estimated 27m 51s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 98
# run example number: 16 of 20 for pic_v_4.tif
# Starting simulation at t=53.5 s for a duration of 0.45 s
# 0.0029335495829466447 (0%) simulated in 10s, estimated 25m 24s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 81
# run example number: 17 of 20 for pic_v_4.tif
# Starting simulation at t=54.2 s for a duration of 0.45 s
# 0.002849039341262021 (0%) simulated in 10s, estimated 26m 10s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 137
# run example number: 18 of 20 for pic_v_4.tif
# Starting simulation at t=54.9 s for a duration of 0.45 s
# 0.0026520325203246804 (0%) simulated in 10s, estimated 28m 7s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 42
# run example number: 19 of 20 for pic_v_4.tif
# Starting simulation at t=55.6 s for a duration of 0.45 s
# 0.002622123104370516 (0%) simulated in 10s, estimated 28m 26s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 84
# run example number: 20 of 20 for pic_v_4.tif
# Starting simulation at t=56.3 s for a duration of 0.45 s
# 0.003033039647576527 (0%) simulated in 10s, estimated 24m 36s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 92
# run example number: 1 of 20 for pic_v_5.tif
# Starting simulation at t=57.25 s for a duration of 0.45 s
# 0.0025876949740028625 (0%) simulated in 10s, estimated 28m 50s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 107
# run example number: 2 of 20 for pic_v_5.tif
# Starting simulation at t=57.95 s for a duration of 0.45 s
# 0.0024202910958898314 (0%) simulated in 10s, estimated 30m 52s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 200
# run example number: 3 of 20 for pic_v_5.tif
# Starting simulation at t=58.65 s for a duration of 0.45 s
# 0.0023550761421313837 (0%) simulated in 10s, estimated 31m 41s remaining.
# 0.45 (100%) simulated in 15s
# S - spike count 119
# run example number: 4 of 20 for pic_v_5.tif
# Starting simulation at t=59.35 s for a duration of 0.45 s
# 0.002505852842808707 (0%) simulated in 10s, estimated 29m 46s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 155
# run example number: 5 of 20 for pic_v_5.tif
# Starting simulation at t=60.05 s for a duration of 0.45 s
# 0.002260413223139849 (0%) simulated in 10s, estimated 33m 2s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 118
# run example number: 6 of 20 for pic_v_5.tif
# Starting simulation at t=60.75 s for a duration of 0.45 s
# 0.002587499999999321 (0%) simulated in 10s, estimated 28m 49s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 128
# run example number: 7 of 20 for pic_v_5.tif
# Starting simulation at t=61.45 s for a duration of 0.45 s
# 0.0021438610662351774 (0%) simulated in 10s, estimated 34m 49s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 115
# run example number: 8 of 20 for pic_v_5.tif
# Starting simulation at t=62.15 s for a duration of 0.45 s
# 0.0023873003194881284 (0%) simulated in 10s, estimated 31m 15s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 64
# run example number: 9 of 20 for pic_v_5.tif
# Starting simulation at t=62.85 s for a duration of 0.45 s
# 0.002107819905212572 (0%) simulated in 10s, estimated 35m 26s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 210
# run example number: 10 of 20 for pic_v_5.tif
# Starting simulation at t=63.55 s for a duration of 0.45 s
# 0.002629687499999313 (0%) simulated in 10s, estimated 28m 22s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 165
# run example number: 11 of 20 for pic_v_5.tif
# Starting simulation at t=64.25 s for a duration of 0.45 s
# 0.0022305255023177127 (0%) simulated in 10s, estimated 33m 28s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 163
# run example number: 12 of 20 for pic_v_5.tif
# Starting simulation at t=64.95 s for a duration of 0.45 s
# 0.0020759174311919507 (0%) simulated in 10s, estimated 35m 59s remaining.
# 0.45 (100%) simulated in 15s
# S - spike count 97
# run example number: 13 of 20 for pic_v_5.tif
# Starting simulation at t=65.65 s for a duration of 0.45 s
# 0.0014745839636906947 (0%) simulated in 10s, estimated 50m 42s remaining.
# 0.002006959152798076 (0%) simulated in 20s, estimated 1h 14m 42s remaining.
# 0.0027571860816937286 (0%) simulated in 30s, estimated 1h 21m 20s remaining.
# 0.45 (100%) simulated in 33s
# S - spike count 133
# run example number: 14 of 20 for pic_v_5.tif
# Starting simulation at t=66.35 s for a duration of 0.45 s
# 0.0016544910179633724 (0%) simulated in 10s, estimated 45m 11s remaining.
# 0.45 (100%) simulated in 17s
# S - spike count 115
# run example number: 15 of 20 for pic_v_5.tif
# Starting simulation at t=67.05 s for a duration of 0.45 s
# 0.0016133333333326024 (0%) simulated in 10s, estimated 46m 20s remaining.
# 0.45 (100%) simulated in 18s
# S - spike count 85
# run example number: 16 of 20 for pic_v_5.tif
# Starting simulation at t=67.75 s for a duration of 0.45 s
# 0.0008346774193541345 (0%) simulated in 10s, estimated 1h 29m 49s remaining.
# 0.0021793988269787727 (0%) simulated in 20s, estimated 1h 8m 33s remaining.
# 0.45 (100%) simulated in 23s
# S - spike count 125
# run example number: 17 of 20 for pic_v_5.tif
# Starting simulation at t=68.45 s for a duration of 0.45 s
# 0.0022539187227859155 (0%) simulated in 10s, estimated 33m 7s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 168
# run example number: 18 of 20 for pic_v_5.tif
# Starting simulation at t=69.15 s for a duration of 0.45 s
# 0.0015853448275854494 (0%) simulated in 10s, estimated 47m 9s remaining.
# 0.45 (100%) simulated in 18s
# S - spike count 126
# run example number: 19 of 20 for pic_v_5.tif
# Starting simulation at t=69.85 s for a duration of 0.45 s
# 0.0017628733997147137 (0%) simulated in 10s, estimated 42m 25s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 72
# run example number: 20 of 20 for pic_v_5.tif
# Starting simulation at t=70.55 s for a duration of 0.45 s
# 0.0016814788732386898 (0%) simulated in 10s, estimated 44m 27s remaining.
# 0.45 (100%) simulated in 17s
# S - spike count 112
# run example number: 1 of 20 for pic_v_6.tif
# Starting simulation at t=71.5 s for a duration of 0.45 s
# 0.0015248088950652614 (0%) simulated in 10s, estimated 49m 1s remaining.
# 0.45 (100%) simulated in 17s
# S - spike count 180
# run example number: 2 of 20 for pic_v_6.tif
# Starting simulation at t=72.2 s for a duration of 0.45 s
# 0.0015249827942180735 (0%) simulated in 10s, estimated 49m 1s remaining.
# 0.45 (100%) simulated in 17s
# S - spike count 125
# run example number: 3 of 20 for pic_v_6.tif
# Starting simulation at t=72.9 s for a duration of 0.45 s
# 0.0016196319018396774 (0%) simulated in 10s, estimated 46m 9s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 194
# run example number: 4 of 20 for pic_v_6.tif
# Starting simulation at t=73.6 s for a duration of 0.45 s
# 0.001806684672517744 (0%) simulated in 10s, estimated 41m 22s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 205
# run example number: 5 of 20 for pic_v_6.tif
# Starting simulation at t=74.3 s for a duration of 0.45 s
# 0.0017103010033436793 (0%) simulated in 10s, estimated 43m 42s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 213
# run example number: 6 of 20 for pic_v_6.tif
# Starting simulation at t=75. s for a duration of 0.45 s
# 0.001211332007951474 (0%) simulated in 10s, estimated 1h 1m 46s remaining.
# 0.0021817097415498875 (0%) simulated in 20s, estimated 1h 8m 26s remaining.
# 0.45 (100%) simulated in 24s
# S - spike count 182
# run example number: 7 of 20 for pic_v_6.tif
# Starting simulation at t=75.7 s for a duration of 0.45 s
# 0.0016841759684823935 (0%) simulated in 10s, estimated 44m 22s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 149
# run example number: 8 of 20 for pic_v_6.tif
# Starting simulation at t=76.4 s for a duration of 0.45 s
# 0.0015359141184116347 (0%) simulated in 10s, estimated 48m 40s remaining.
# 0.45 (100%) simulated in 19s
# S - spike count 78
# run example number: 9 of 20 for pic_v_6.tif
# Starting simulation at t=77.1 s for a duration of 0.45 s
# 0.0015371373307535084 (0%) simulated in 10s, estimated 48m 39s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 137
# run example number: 10 of 20 for pic_v_6.tif
# Starting simulation at t=77.8 s for a duration of 0.45 s
# 0.001434824281149326 (0%) simulated in 10s, estimated 52m 6s remaining.
# 0.45 (100%) simulated in 19s
# S - spike count 137
# run example number: 11 of 20 for pic_v_6.tif
# Starting simulation at t=78.5 s for a duration of 0.45 s
# 0.0009786573780865117 (0%) simulated in 10s, estimated 1h 16m 29s remaining.
# 0.002490816972766665 (0%) simulated in 20s, estimated 59m 54s remaining.
# 0.45 (100%) simulated in 20s
# S - spike count 149
# run example number: 12 of 20 for pic_v_6.tif
# Starting simulation at t=79.2 s for a duration of 0.45 s
# 0.001537288135592304 (0%) simulated in 10s, estimated 48m 38s remaining.
# 0.45 (100%) simulated in 17s
# S - spike count 156
# run example number: 13 of 20 for pic_v_6.tif
# Starting simulation at t=79.9 s for a duration of 0.45 s
# 0.0015574984443052532 (0%) simulated in 10s, estimated 48m 0s remaining.
# 0.45 (100%) simulated in 15s
# S - spike count 129
# run example number: 14 of 20 for pic_v_6.tif
# Starting simulation at t=80.6 s for a duration of 0.45 s
# 0.0015157310302273616 (0%) simulated in 10s, estimated 49m 20s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 175
# run example number: 15 of 20 for pic_v_6.tif
# Starting simulation at t=81.3 s for a duration of 0.45 s
# 0.0011939449541275523 (0%) simulated in 10s, estimated 1h 2m 39s remaining.
# 0.45 (100%) simulated in 19s
# S - spike count 135
# run example number: 16 of 20 for pic_v_6.tif
# Starting simulation at t=82. s for a duration of 0.45 s
# 0.0015822316555478995 (0%) simulated in 10s, estimated 47m 18s remaining.
# 0.0024412977562149442 (0%) simulated in 20s, estimated 1h 1m 9s remaining.
# 0.45 (100%) simulated in 20s
# S - spike count 105
# run example number: 17 of 20 for pic_v_6.tif
# Starting simulation at t=82.7 s for a duration of 0.45 s
# 0.0012945279615143904 (0%) simulated in 10s, estimated 57m 49s remaining.
# 0.002304389657244988 (0%) simulated in 20s, estimated 1h 4m 47s remaining.
# 0.45 (100%) simulated in 20s
# S - spike count 122
# run example number: 18 of 20 for pic_v_6.tif
# Starting simulation at t=83.4 s for a duration of 0.45 s
# 0.0014152057245071321 (0%) simulated in 10s, estimated 52m 51s remaining.
# 0.45 (100%) simulated in 17s
# S - spike count 80
# run example number: 19 of 20 for pic_v_6.tif
# Starting simulation at t=84.1 s for a duration of 0.45 s
# 0.001415730337077694 (0%) simulated in 10s, estimated 52m 49s remaining.
# 0.45 (100%) simulated in 17s
# S - spike count 59
# run example number: 20 of 20 for pic_v_6.tif
# Starting simulation at t=84.8 s for a duration of 0.45 s
# 0.0014669208211134043 (0%) simulated in 10s, estimated 50m 58s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 102
# run example number: 1 of 20 for pic_v_7.tif
# Starting simulation at t=85.75 s for a duration of 0.45 s
# 0.0008942575406022936 (0%) simulated in 10s, estimated 1h 23m 43s remaining.
# 0.0018167053364259405 (0%) simulated in 20s, estimated 1h 22m 14s remaining.
# 0.45 (100%) simulated in 23s
# S - spike count 109
# run example number: 2 of 20 for pic_v_7.tif
# Starting simulation at t=86.45 s for a duration of 0.45 s
# 0.0011470080552349756 (0%) simulated in 10s, estimated 1h 5m 15s remaining.
# 0.45 (100%) simulated in 19s
# S - spike count 175
# run example number: 3 of 20 for pic_v_7.tif
# Starting simulation at t=87.15 s for a duration of 0.45 s
# 0.001396232876711371 (0%) simulated in 10s, estimated 53m 33s remaining.
# 0.45 (100%) simulated in 17s
# S - spike count 194
# run example number: 4 of 20 for pic_v_7.tif
# Starting simulation at t=87.85 s for a duration of 0.45 s
# 0.0014075877689684203 (0%) simulated in 10s, estimated 53m 11s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 157
# run example number: 5 of 20 for pic_v_7.tif
# Starting simulation at t=88.55 s for a duration of 0.45 s
# 0.0013707303370776634 (0%) simulated in 10s, estimated 54m 36s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 238
# run example number: 6 of 20 for pic_v_7.tif
# Starting simulation at t=89.25 s for a duration of 0.45 s
# 0.001284782608694669 (0%) simulated in 10s, estimated 58m 13s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 151
# run example number: 7 of 20 for pic_v_7.tif
# Starting simulation at t=89.95 s for a duration of 0.45 s
# 0.0013156526548662919 (0%) simulated in 10s, estimated 56m 52s remaining.
# 0.002217146017698152 (0%) simulated in 20s, estimated 1h 7m 21s remaining.
# 0.45 (100%) simulated in 20s
# S - spike count 211
# run example number: 8 of 20 for pic_v_7.tif
# Starting simulation at t=90.65 s for a duration of 0.45 s
# 0.0008891328210747198 (0%) simulated in 10s, estimated 1h 24m 12s remaining.
# 0.002117618002194363 (0%) simulated in 20s, estimated 1h 10m 31s remaining.
# 0.45 (100%) simulated in 21s
# S - spike count 244
# run example number: 9 of 20 for pic_v_7.tif
# Starting simulation at t=91.35 s for a duration of 0.45 s
# 0.0007284313725480517 (0%) simulated in 10s, estimated 1h 42m 50s remaining.
# 0.0015053921568617236 (0%) simulated in 20s, estimated 1h 39m 20s remaining.
# 0.45 (100%) simulated in 29s
# S - spike count 170
# run example number: 10 of 20 for pic_v_7.tif
# Starting simulation at t=92.05 s for a duration of 0.45 s
# 0.0009403783783773771 (0%) simulated in 10s, estimated 1h 19m 37s remaining.
# 0.0018359999999990005 (0%) simulated in 20s, estimated 1h 21m 35s remaining.
# 0.45 (100%) simulated in 26s
# S - spike count 79
# run example number: 11 of 20 for pic_v_7.tif
# Starting simulation at t=92.75 s for a duration of 0.45 s
# 0.0012239806866942591 (0%) simulated in 10s, estimated 1h 1m 7s remaining.
# 0.45 (100%) simulated in 17s
# S - spike count 90
# run example number: 12 of 20 for pic_v_7.tif
# Starting simulation at t=93.45 s for a duration of 0.45 s
# 0.0010969648562289883 (0%) simulated in 10s, estimated 1h 8m 14s remaining.
# 0.45 (100%) simulated in 18s
# S - spike count 106
# run example number: 13 of 20 for pic_v_7.tif
# Starting simulation at t=94.15 s for a duration of 0.45 s
# 0.0013176532769545903 (0%) simulated in 10s, estimated 56m 46s remaining.
# 0.45 (100%) simulated in 17s
# S - spike count 106
# run example number: 14 of 20 for pic_v_7.tif
# Starting simulation at t=94.85 s for a duration of 0.45 s
# 0.0011847324239234467 (0%) simulated in 10s, estimated 1h 3m 9s remaining.
# 0.45 (100%) simulated in 18s
# S - spike count 70
# run example number: 15 of 20 for pic_v_7.tif
# Starting simulation at t=95.55 s for a duration of 0.45 s
# 0.001280624999998944 (0%) simulated in 10s, estimated 58m 24s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 66
# run example number: 16 of 20 for pic_v_7.tif
# Starting simulation at t=96.25 s for a duration of 0.45 s
# 0.0012871768355728881 (0%) simulated in 10s, estimated 58m 6s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 132
# run example number: 17 of 20 for pic_v_7.tif
# Starting simulation at t=96.95 s for a duration of 0.45 s
# 0.0012705338809024635 (0%) simulated in 10s, estimated 58m 52s remaining.
# 0.45 (100%) simulated in 17s
# S - spike count 111
# run example number: 18 of 20 for pic_v_7.tif
# Starting simulation at t=97.65 s for a duration of 0.45 s
# 0.0012527522935769332 (0%) simulated in 10s, estimated 59m 42s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 120
# run example number: 19 of 20 for pic_v_7.tif
# Starting simulation at t=98.35 s for a duration of 0.45 s
# 0.0007569838056669298 (0%) simulated in 10s, estimated 1h 38m 56s remaining.
# 0.0018059210526305534 (0%) simulated in 20s, estimated 1h 22m 46s remaining.
# 0.45 (100%) simulated in 23s
# S - spike count 93
# run example number: 20 of 20 for pic_v_7.tif
# Starting simulation at t=99.05 s for a duration of 0.45 s
# 0.0009922613065316017 (0%) simulated in 10s, estimated 1h 15m 25s remaining.
# 0.0018741708542702623 (0%) simulated in 20s, estimated 1h 19m 46s remaining.
# 0.45 (100%) simulated in 21s
# S - spike count 55
# run example number: 1 of 20 for pic_v_8.tif
# Starting simulation at t=100. s for a duration of 0.45 s
# 0.0007508213041303573 (0%) simulated in 10s, estimated 1h 39m 45s remaining.
# 0.0012655550024877101 (0%) simulated in 20s, estimated 1h 58m 13s remaining.
# 0.45 (100%) simulated in 25s
# S - spike count 163
# run example number: 2 of 20 for pic_v_8.tif
# Starting simulation at t=100.7 s for a duration of 0.45 s
# 0.0013408798813632368 (0%) simulated in 10s, estimated 56m 3s remaining.
# 0.45 (100%) simulated in 17s
# S - spike count 185
# run example number: 3 of 20 for pic_v_8.tif
# Starting simulation at t=101.4 s for a duration of 0.45 s
# 0.0011129602356396053 (0%) simulated in 10s, estimated 1h 7m 13s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 139
# run example number: 4 of 20 for pic_v_8.tif
# Starting simulation at t=102.1 s for a duration of 0.45 s
# 0.0010557776694284865 (0%) simulated in 10s, estimated 1h 10m 54s remaining.
# 0.45 (100%) simulated in 18s
# S - spike count 162
# run example number: 5 of 20 for pic_v_8.tif
# Starting simulation at t=102.8 s for a duration of 0.45 s
# 0.001093510895882666 (0%) simulated in 10s, estimated 1h 8m 27s remaining.
# 0.001514963680386352 (0%) simulated in 20s, estimated 1h 38m 43s remaining.
# 0.45 (100%) simulated in 23s
# S - spike count 202
# run example number: 6 of 20 for pic_v_8.tif
# Starting simulation at t=103.5 s for a duration of 0.45 s
# 0.0015796536796525934 (0%) simulated in 10s, estimated 47m 19s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 186
# run example number: 7 of 20 for pic_v_8.tif
# Starting simulation at t=104.2 s for a duration of 0.45 s
# 0.0015088867654073827 (0%) simulated in 10s, estimated 49m 33s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 180
# run example number: 8 of 20 for pic_v_8.tif
# Starting simulation at t=104.9 s for a duration of 0.45 s
# 0.0015138111058365803 (0%) simulated in 10s, estimated 49m 24s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 141
# run example number: 9 of 20 for pic_v_8.tif
# Starting simulation at t=105.6 s for a duration of 0.45 s
# 0.0011338048090512563 (0%) simulated in 10s, estimated 1h 6m 0s remaining.
# 0.45 (100%) simulated in 17s
# S - spike count 123
# run example number: 10 of 20 for pic_v_8.tif
# Starting simulation at t=106.3 s for a duration of 0.45 s
# 0.0012970960187342687 (0%) simulated in 10s, estimated 57m 40s remaining.
# 0.45 (100%) simulated in 14s
# S - spike count 150
# run example number: 11 of 20 for pic_v_8.tif
# Starting simulation at t=107. s for a duration of 0.45 s
# 0.001578873894833712 (0%) simulated in 10s, estimated 47m 20s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 107
# run example number: 12 of 20 for pic_v_8.tif
# Starting simulation at t=107.7 s for a duration of 0.45 s
# 0.001494590846046035 (0%) simulated in 10s, estimated 50m 1s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 116
# run example number: 13 of 20 for pic_v_8.tif
# Starting simulation at t=108.4 s for a duration of 0.45 s
# 0.0014672025723461498 (0%) simulated in 10s, estimated 50m 57s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 94
# run example number: 14 of 20 for pic_v_8.tif
# Starting simulation at t=109.1 s for a duration of 0.45 s
# 0.001524783204015325 (0%) simulated in 10s, estimated 49m 2s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 106
# run example number: 15 of 20 for pic_v_8.tif
# Starting simulation at t=109.8 s for a duration of 0.45 s
# 0.0014497959183662264 (0%) simulated in 10s, estimated 51m 35s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 83
# run example number: 16 of 20 for pic_v_8.tif
# Starting simulation at t=110.5 s for a duration of 0.45 s
# 0.0012183866606568406 (0%) simulated in 10s, estimated 1h 1m 24s remaining.
# 0.45 (100%) simulated in 15s
# S - spike count 73
# run example number: 17 of 20 for pic_v_8.tif
# Starting simulation at t=111.2 s for a duration of 0.45 s
# 0.00150698611732982 (0%) simulated in 10s, estimated 49m 36s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 61
# run example number: 18 of 20 for pic_v_8.tif
# Starting simulation at t=111.9 s for a duration of 0.45 s
# 0.0014467289719614612 (0%) simulated in 10s, estimated 51m 41s remaining.
# 0.45 (100%) simulated in 12s
# S - spike count 159
# run example number: 19 of 20 for pic_v_8.tif
# Starting simulation at t=112.6 s for a duration of 0.45 s
# 0.0010819106589993039 (0%) simulated in 10s, estimated 1h 9m 11s remaining.
# 0.45 (100%) simulated in 16s
# S - spike count 113
# run example number: 20 of 20 for pic_v_8.tif
# Starting simulation at t=113.3 s for a duration of 0.45 s
# 0.0012421978021966468 (0%) simulated in 10s, estimated 1h 0m 13s remaining.
# 0.45 (100%) simulated in 13s
# S - spike count 49

# %%
c_shape = (c_length, c_length, orientations)
r_shape = (r_length, r_length)
fig, axarr = subplots(2,5, figsize = (15, 7))

data = np.copy(spike_monitors['L3'].count).reshape(c_shape).transpose()
v_min = data.min(); v_max = data.max()
print('L3 v_min', v_min, 'v_max', v_max)

im3 = axarr[0,0].imshow(data[h_index].transpose(), vmax=v_max, vmin=v_min, cmap = cmap.get_cmap('binary'))
axarr[0,0].title.set_text('L3_h'); 
plt.colorbar(im3, ax=axarr[0,0])
im3 = axarr[1,0].imshow(data[v_index].transpose(), vmax=v_max, vmin=v_min, cmap = cmap.get_cmap('binary'))
axarr[1,0].title.set_text('L3_v'); 
plt.colorbar(im3, ax=axarr[1,0])
im3 = axarr[0,1].imshow(data[d1_index].transpose(), vmax=v_max, vmin=v_min, cmap = cmap.get_cmap('binary'))
axarr[0,1].title.set_text('L3_d1');
plt.colorbar(im3, ax=axarr[0,1])
im3 = axarr[1,1].imshow(data[d2_index].transpose(), vmax=v_max, vmin=v_min, cmap = cmap.get_cmap('binary'))
axarr[1,1].title.set_text('L3_d2');
plt.colorbar(im3, ax=axarr[1,1])


data = np.copy(spike_monitors['L4'].count).reshape(c_shape).transpose()
v_min = data.min(); v_max = data.max()
print('L4 v_min', v_min, 'v_max', v_max)

im4 = axarr[0,2].imshow(data[h_index].transpose(), vmax=v_max, vmin=v_min, cmap = cmap.get_cmap('binary'))
axarr[0,2].title.set_text('L4_h')
plt.colorbar(im4, ax=axarr[0,2])
im4 = axarr[1,2].imshow(data[v_index].transpose(), vmax=v_max, vmin=v_min, cmap = cmap.get_cmap('binary'))
axarr[1,2].title.set_text('L4_v')
plt.colorbar(im4, ax=axarr[1,2])
im4 = axarr[0,3].imshow(data[d1_index].transpose(), vmax=v_max, vmin=v_min, cmap = cmap.get_cmap('binary'))
axarr[0,3].title.set_text('L4_d1')
plt.colorbar(im4, ax=axarr[0,3])
im4 = axarr[1,3].imshow(data[d2_index].transpose(), vmax=v_max, vmin=v_min, cmap = cmap.get_cmap('binary'))
axarr[1,3].title.set_text('L4_d2')
plt.colorbar(im4, ax=axarr[1,3])


data = np.copy(spike_monitors['LGN_on'].count).reshape(r_shape)
v_min = data.min(); v_max = data.max()
axarr[0,4].imshow(data, vmax=v_max, vmin=v_min, cmap = cmap.get_cmap('binary'))
axarr[0,4].title.set_text('LGN_on')

data = np.copy(spike_monitors['LGN_off'].count).reshape(r_shape)
v_min = data.min(); v_max = data.max()
axarr[1,4].imshow(data, vmax=v_max, vmin=v_min, cmap = cmap.get_cmap('binary'))
axarr[1,4].title.set_text('LGN_off')
# Out:
# L3 v_min 0 v_max 34
# L4 v_min 0 v_max 37

# %%
gc.collect()
# Out:
# 47408

# %%
plot_lateral_distribution('L3_L3')
# Out:
# hh 979.6484897139713 of 16049.584464095855 : 6.10388693804204
# hv 937.7931852157126 of 16049.584464095855 : 5.84309947284696
# hd1 939.23423483585 of 16049.584464095855 : 5.852078207613341
# hd2 926.4798772522289 of 16049.584464095855 : 5.772609747777802
# vh 940.2545070548792 of 16049.584464095855 : 5.858435208452283
# vv 1660.21229598503 of 16049.584464095855 : 10.344269658189916
# vd1 1028.1061219188205 of 16049.584464095855 : 6.405811466451186
# vd2 932.2937119958488 of 16049.584464095855 : 5.8088339550563495
# d1h 939.3515444300461 of 16049.584464095855 : 5.852809127435338
# d1v 1036.4778227059478 of 16049.584464095855 : 6.457972946431278
# d1d1 1071.3449654765868 of 16049.584464095855 : 6.675219335885407
# d1d2 937.9661777349298 of 16049.584464095855 : 5.844177335763625
# d2h 924.6617653221458 of 16049.584464095855 : 5.761281654305036
# d2v 929.3050750201958 of 16049.584464095855 : 5.790212681824394
# d2d1 933.153539240067 of 16049.584464095855 : 5.814191272849478
# d2d2 933.3011501935982 of 16049.584464095855 : 5.815110991075589

# %%
# plot_lateral_distribution('L3_L2')

# %%
# save connections
save_connections()
# Out:
# LGN_on_L4_NF LGN_off_L4_NF LGN_off_L4_i_NF LGN_on_L4_i_NF LGN_off_L4_FN LGN_on_L4_FN LGN_on_L4_i_FN LGN_off_L4_i_FN L4_i_L4_NF L4_i_L4_FN L4_NF_L4 L4_FN_L4 L4_L3 L3_L3 L3_L2 L2_L3 L3_L4 connections saved

# %%
plot(spike_monitors['LGN_on'].t/ms, spike_monitors['LGN_on'].i, '.k')
xlabel('Time (ms)')
ylabel('Neuron index');

# %%
plot(spike_monitors['L4'].t/ms, spike_monitors['L4'].i, '.k')
xlabel('Time (ms)')
ylabel('Neuron index');

# %%
plot(spike_monitors['L3'].t/ms, spike_monitors['L3'].i, '.k')
xlabel('Time (ms)')
ylabel('Neuron index');

# %%
plot(spike_monitors['L2'].t/ms, spike_monitors['L2'].i, '.k')
xlabel('Time (ms)')
ylabel('Neuron index');

# %%
# spike_monitors['L3'].i

# %%
# junction point V 0 0
# junction point H 0 0
# junction left H 9 11
# junction down V 11 12
print("junction point V", spike_monitors['L3'].count[(2*c_length + 12)*orientations + v_index])
print("junction point H", spike_monitors['L3'].count[(2*c_length + 12)*orientations + h_index])
print("junction left H", spike_monitors['L3'].count[(2*c_length + 11)*orientations + h_index])
print("junction down V", spike_monitors['L3'].count[(3*c_length + 12)*orientations + v_index])
# Out:
# junction point V 28
# junction point H 4
# junction left H 6
# junction down V 27

# %%
# Line point V 0 0
# Line point H 0 0
# Line Up V 12 10
# Line Down V 10 10
print("Line point V", spike_monitors['L3'].count[(7*c_length + 12)*orientations + v_index])
print("Line point H", spike_monitors['L3'].count[(7*c_length + 12)*orientations + h_index])
print("Line Up V", spike_monitors['L3'].count[(6*c_length + 12)*orientations + v_index])
print("Line Down V", spike_monitors['L3'].count[(8*c_length + 12)*orientations + v_index])
# Out:
# Line point V 24
# Line point H 3
# Line Up V 25
# Line Down V 25

# %%
print(max(spike_monitors['L3'].count))
print(min(spike_monitors['L3'].count))
# Out:
# 34
# 0

# %%
print(max(spike_monitors['L4'].count))
print(min(spike_monitors['L4'].count))
# Out:
# 37
# 0
